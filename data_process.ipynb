# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
jwst.nircam.F090W & jwst.nircam.F150W & jwst.nircam.F200W & jwst.nircam.F277W & jwst.nircam.F356W & jwst.nircam.F444W & jwst.miri.F770W & jwst.miri.F1000W & jwst.miri.F1500W

# %% [markdown]
# PIXAR_SR Nominal pixel area in steradians
# 090 2.22771413816626E-14
# 150 2.292514304171E-14
# 200 2.22771413816626E-14
# 277 9.30710330396321E-14
# 356 9.30710330396321E-14
# 444 9.30710330396321E-14

# %%
sr2pix=[2.22771413816626*10**-14,
2.292514304171*10**-14,
2.22771413816626*10**-14,
9.30710330396321*10**-14,
9.30710330396321*10**-14,
9.30710330396321*10**-14]

# %% [markdown]
# processing match catalog
# match1:7 10 15
# match2: 10 15 18
# match3: 15 18 21

# %%
match1=pd.read_csv('/home/leolin/JWST_data/CEERS/match_7_10_15.csv')
match2=pd.read_csv('/home/leolin/JWST_data/CEERS/match_10_15_18.csv')
match3=pd.read_csv('/home/leolin/JWST_data/CEERS/match_15_18_21.csv')

match1_column=match1.columns
match2_column=match2.columns
match3_column=match3.columns

# %%
match1_column
# Out:
# Index(['id_1', 'FLUX_APER_1', 'FLUXERR_APER_1', 'ALPHA_J2000_1',
#        'DELTA_J2000_1', 'CLASS_STAR_1', 'id_2', 'FLUX_APER_2',
#        'FLUXERR_APER_2', 'ALPHA_J2000_2', 'DELTA_J2000_2', 'CLASS_STAR_2',
#        'id_3', 'FLUX_APER_3', 'FLUXERR_APER_3', 'ALPHA_J2000_3',
#        'DELTA_J2000_3', 'CLASS_STAR_3'],
#       dtype='object')

# %%
df=match1
df['F770W_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['F770W_Jy_err']=df['FLUXERR_APER_1']*2.844*10**-7
df['M770W_abmag']=-2.5 * np.log10(df['F770W_Jy']/3631)
df['M770W_abmag_err']=2.5 * df['F770W_Jy_err']/df['F770W_Jy']/np.log(10)


df['F1000W_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['F1000W_Jy_err']=df['FLUXERR_APER_2']*2.844*10**-7
df['M1000W_abmag']=-2.5 * np.log10(df['F1000W_Jy']/3631)
df['M1000W_abmag_err']=2.5 * df['F1000W_Jy_err']/df['F1000W_Jy']/np.log(10)


df['F1500W_Jy']=df['FLUX_APER_3']*2.844*10**-7
df['F1500W_Jy_err']=df['FLUXERR_APER_3']*2.844*10**-7
df['M1500W_abmag']=-2.5 * np.log10(df['F1500W_Jy']/3631)
df['M1500W_abmag_err']=2.5 * df['F1500W_Jy_err']/df['F1500W_Jy']/np.log(10)


df['f10/f7']=df['F1000W_Jy']/df['F770W_Jy']
df['f15/f10']=df['F1500W_Jy']/df['F1000W_Jy']
# 'ALPHA_J2000_1','DELTA_J2000_1',
match_re1=df

pah_002=match_re1[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]
pah_006=match_re1[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]


f10_f7=np.log10(df['f10/f7'])
f15_f10=np.log10(df['f15/f10'])
plt.plot(f10_f7,f15_f10,'o')
plt.xlabel('log(f10/f7.7)')
plt.ylabel('log(f15/f10)')
plt.savefig('CEERS_ccplot_7_10_15.png')

# %%
df=match2
df['F1000W_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['F1000W_Jy_err']=df['FLUXERR_APER_1']*2.844*10**-7
df['M1000W_abmag']=-2.5 * np.log10(df['F1000W_Jy']/3631)
df['M1000W_abmag_err']=2.5 * df['F1000W_Jy_err']/df['F1000W_Jy']/np.log(10)


df['F1500W_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['F1500W_Jy_err']=df['FLUXERR_APER_2']*2.844*10**-7
df['M1500W_abmag']=-2.5 * np.log10(df['F1500W_Jy']/3631)
df['M1500W_abmag_err']=2.5 * df['F1500W_Jy_err']/df['F1500W_Jy']/np.log(10)


df['F1800W_Jy']=df['FLUX_APER_3']*2.844*10**-7
df['F1800W_Jy_err']=df['FLUXERR_APER_3']*2.844*10**-7
df['M1800W_abmag']=-2.5 * np.log10(df['F1800W_Jy']/3631)
df['M1800W_abmag_err']=2.5 * df['F1800W_Jy_err']/df['F1800W_Jy']/np.log(10)


df['f15/f10']=df['F1500W_Jy']/df['F1000W_Jy']
df['f18/f15']=df['F1800W_Jy']/df['F1500W_Jy']
# 'ALPHA_J2000_1','DELTA_J2000_1',
match_re2=df

# pah_002=match_re2[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]
# pah_006=match_re2[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]


f15_f10=np.log10(match_re2['f15/f10'])
f18_f15=np.log10(match_re2['f18/f15'])
plt.plot(f15_f10,f18_f15,'o')
plt.xlabel('log(f15/f10)')
plt.ylabel('log(f18/f15)')
plt.savefig('CEERS_ccplot_10_15_18.png')
# Out:
# /tmp/ipykernel_18812/57748646.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pah_002=match_re2[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]
# /tmp/ipykernel_18812/57748646.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pah_006=match_re2[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]

# %%
df=match3
df['F1500W_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['F1500W_Jy_err']=df['FLUXERR_APER_1']*2.844*10**-7
df['M1500W_abmag']=-2.5 * np.log10(df['F1500W_Jy']/3631)
df['M1500W_abmag_err']=2.5 * df['F1500W_Jy_err']/df['F1500W_Jy']/np.log(10)


df['F1800W_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['F1800W_Jy_err']=df['FLUXERR_APER_2']*2.844*10**-7
df['M1800W_abmag']=-2.5 * np.log10(df['F1800W_Jy']/3631)
df['M1800W_abmag_err']=2.5 * df['F1800W_Jy_err']/df['F1800W_Jy']/np.log(10)


df['F2100W_Jy']=df['FLUX_APER_3']*2.844*10**-7
df['F2100W_Jy_err']=df['FLUXERR_APER_3']*2.844*10**-7
df['M2100W_abmag']=-2.5 * np.log10(df['F2100W_Jy']/3631)
df['M2100W_abmag_err']=2.5 * df['F2100W_Jy_err']/df['F2100W_Jy']/np.log(10)


df['f18/f15']=df['F1800W_Jy']/df['F1500W_Jy']
df['f21/f18']=df['F2100W_Jy']/df['F1800W_Jy']
# 'ALPHA_J2000_1','DELTA_J2000_1',
match_re3=df

# pah_002=match_re2[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]
# pah_006=match_re2[ (match_re1['f10/f7']>10**0.75)|(match_re1['f15/f10']>10**0.8) ]


f18_f15=np.log10(match_re3['f18/f15'])
f21_f18=np.log10(match_re3['f21/f18'])
plt.plot(f18_f15,f21_f18,'o')
plt.xlabel('log(f18/f15)')
plt.ylabel('log(f21/f18)')
plt.savefig('CEERS_ccplot_15_18_21.png')

# %%
hst=match_re1[['id_1','ALPHA_J2000_1','DELTA_J2000_1']]
hst.columns=['target','ra','dec']
hst.to_csv('match1.csv',index=None)

# %%
match1_column=match1.columns
match2_column=match2.columns
match3_column=match3.columns
print(match1_column[2])
# Out:
# FLUXERR_APER_1

# %%
pz_002=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/sed_list_002_photoz.csv',index_col=0)
pz_006=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/sed_list_006_photoz.csv',index_col=0)

# %%
pz_002['z_best'].iloc[5]
# Out:
# 3.8284

# %% [markdown]
# NIR match and waveleng-flux sed fitting plot

# %% [markdown]
# 002

# %%
nirfile=['/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/002/match_band_1',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/002/match_band_2',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/002/match_band_3',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/002/match_band_4',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/002/match_band_5',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/002/match_band_6']
file=[0 for i in range(6)]
for i, a in enumerate(nirfile):
    if i>-1:    
        df=pd.read_csv(a,index_col=0)
        file[i]=df.drop_duplicates(subset=['col1_1'])
        # print(file[i])
    # print(df)
        # print(df[['FLUX_APER_1_Jy','FLUX_APER_2_Jy','FLUX_APER_Jy']])
    # print(df['aper70_flux'].iloc[0:5])
file[2]



x=np.array([90,150,200,277,356,444,770,1000,1500])
y=[[] for i in range(len(file[0]))]
for j in range(len(file[0])):
                            
    y[j]+=[file[0]['Ra'].iloc[j],file[0]['Dec'].iloc[j]]
    for i in range(6):
    #  print(len(file[i]))
                                    
        y[j]+=[file[i]['aper70_flux'].iloc[j]]
        y[j]+=[file[i]['aper70_flux_err'].iloc[j]*sr2pix[i]*10**6]                                    
                                
        y[j]+=[-2.5*np.log10(np.abs(file[i]['aper70_flux'].iloc[j])/3631)]
        y[j]+=[2.5 *(file[i][ 'aper70_flux_err'].iloc[j]*sr2pix[i]*10**6/np.abs(file[i]['aper70_flux'].iloc[j]))/np.log(10)]

    y[j]+=[file[0]['FLUX_APER_1_Jy'].iloc[j],file[0]['FLUX_APER_1_Jy_err'].iloc[j],file[0]['MAG_APER_1_abmag'].iloc[j],file[0]['MAG_APER_1_abmag_err'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_2_Jy'].iloc[j],file[0]['FLUX_APER_2_Jy_err'].iloc[j],file[0]['MAG_APER_2_abmag'].iloc[j],file[0]['MAG_APER_2_abmag_err'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_Jy'].iloc[j],file[0]['FLUX_APER_Jy_err'].iloc[j],file[0]['MAG_APER_abmag'].iloc[j],file[0]['MAG_APER_abmag_err'].iloc[j]]


# sed_column=['jwst.nircam.F090W','jwst.nircam.F150W','jwst.nircam.F200W','jwst.nircam.F277W','jwst.nircam.F356W',
# 'jwst.nircam.F444W','jwst.miri.F770W','jwst.miri.F1000W','jwst.miri.F1500W']

sed_column_cigale=['jwst.nircam.F090W', 'jwst.nircam.F090W_err', 'jwst.nircam.F150W', 'jwst.nircam.F150W_err', 
'jwst.nircam.F200W','jwst.nircam.F200W_err','jwst.nircam.F277W', 'jwst.nircam.F277W_err', 
'jwst.nircam.F356W', 'jwst.nircam.F356W_err', 'jwst.nircam.F444W', 'jwst.nircam.F444W_err', 
'jwst.miri.F770W', 'jwst.miri.F770W_err', 'jwst.miri.F1000W', 'jwst.miri.F1000W_err', 
'jwst.miri.F1500W', 'jwst.miri.F1500W_err']

a=['F'+str(band)+'W'+'_flux' for i,band in enumerate(x)]
b=['F'+str(band)+'W'+'_flux_err' for i,band in enumerate(x)]
c=['F'+str(band)+'W'+'_mag' for i,band in enumerate(x)]
d=['F'+str(band)+'W'+'_mag_err' for i,band in enumerate(x)]
sed_column=['Ra','Dec']
for i in range(9):
    sed_column+=[a[i],b[i],c[i],d[i]]

id=[]
for i in range(len(file[0])):
    # print(file[0]['col1_1'].iloc[i])
    id.append(file[0]['col1_1'].iloc[i])


sed=pd.DataFrame(data=y,columns=sed_column,index=id)
sed_list=sed.fillna(99.0)
sed_list=sed_list.drop(index=[66])
sed_list.to_csv('NIR_match/sed_list_002.csv',index_label=' id')

# this is for cigale
# sed_list.insert(0, "redshift", [pz_002['z_best'].iloc[5] for i in range(len(sed_list[0]))], True)
# for i in range(9):
#     sed_list.insert(2*i+2,sed_coloumn[i]+'_err',[99 for i in range(22)])
# sed_list.to_csv('NIR_match/sed_list_002.txt',sep= ' ',index_label=' id')
sed_list_cigale=pd.DataFrame(data=y,index=id)
x=[]
for  i in range(10):    
    x+=[4*i,4*i+1]
# print(x)
sed_list_cigale=sed_list_cigale.drop(columns=x)
sed_list_cigale=sed_list_cigale.fillna(-99.0)
sed_list_cigale=sed_list_cigale.drop(index=[66])
sed_list_cigale.columns=sed_column_cigale
sed_list_cigale.insert(0, "redshift", [pz_002['z_best'].iloc[i] for i in range(len(sed_list_cigale['jwst.nircam.F090W']))], True)
sed_list_cigale.to_csv('NIR_match/sed_pz_002.txt',sep= ' ',index_label=' id')


# for i in range(len(y)):
#     yy=[y[i][4*j+2] for j in range(9)]
#     yer=[y[i][4*j+3] for j in range(9)]
#     plt.errorbar(x/100,yy,yerr=yer,fmt='o')
#     plt.title('002 '+ str(file[0]['col1_1'].iloc[i])+'lambda -flux plot')
#     plt.xlabel('wavelength(micron)')
#     plt.ylabel('flux(Jy)')
#     plt.xlim([0.8,17])
#     plt.xscale('log')
#     plt.yscale('log')
#     plt.savefig(f'NIR_match/002/wavelength_flux/wavelength_flux id'+str(file[0]['col1_1'].iloc[i])+'.png')
#     plt.close()


# for i in range(len(y)):
#     yy=[y[i][4*j+4] for j in range(9)]
#     yer=[y[i][4*j+5] for j in range(9)]
#     # print(yer)
#     plt.errorbar(x/100,yy,yerr=yer,fmt='o')
#     plt.title('002 '+ str(file[0]['col1_1'].iloc[i])+'lambda -abmag plot')
#     plt.xlabel('wavelength(micron)')
#     plt.ylabel('ABmag')
#     plt.xlim([0.8,17])
#     plt.xscale('log')
#     # print(i,max(yy)+1,min(yy)-1)
#     plt.ylim(np.nanmax(yy)+1,np.nanmin(yy)-1)
#     # plt.yscale('log')
#     plt.savefig(f'NIR_match/002/wavelength_flux/wavelength_ABmag id'+str(file[0]['col1_1'].iloc[i])+'.png')
#     plt.close()

# %%
sed_list_cigale
# Out:
#               2             3             6             7             10  \
# 0   7.699501e-07  8.843717e-09  8.493135e-07  6.774608e-09  1.186414e-06
# 1   8.779026e-07  7.283563e-09  1.655536e-06  5.806510e-09  2.258453e-06
# 2   1.725897e-04  1.072825e-07  1.007812e-04  8.251745e-09  1.099521e-04
# 3   1.531980e-07  6.529816e-09  1.522292e-07  4.302247e-09  1.899298e-07
# 4            NaN           NaN           NaN           NaN           NaN
# 5   6.574995e-07  7.897676e-09  2.735415e-06  7.758014e-09  5.784152e-06
# 6   2.463333e-05  2.987065e-08  3.310274e-05  2.345291e-08  4.482236e-05
# 7   2.290001e-07  5.583414e-09  1.341459e-06  4.513384e-09  2.596800e-06
# 8   2.980244e-05  3.767255e-08  1.893092e-05  2.883681e-08  2.070426e-05
# 9   2.812006e-07  7.401386e-09  4.484119e-07  5.458772e-09  6.929412e-07
# 10  1.630138e-07  6.354541e-09  9.651329e-08  4.253464e-09  6.143112e-08
# 11  8.515351e-08  5.757780e-09           NaN           NaN           NaN
# ...

# %%
sed_list_cigale=pd.DataFrame(data=y,index=id)
x=[]
for  i in range(10):    
    x+=[4*i,4*i+1]
# print(x)
sed_list_cigale=sed_list_cigale.drop(columns=x)
sed_list_cigale=sed_list_cigale.drop(index=[66])
sed_list_cigale.columns=sed_column_cigale
sed_list_cigale.insert(0, "redshift", [pz_002['z_best'].iloc[i] for i in range(len(sed_list_cigale['jwst.nircam.F090W']))], True)
# Out:
# [0, 1, 4, 5, 8, 9, 12, 13, 16, 17, 20, 21, 24, 25, 28, 29, 32, 33, 36, 37]

# %% [markdown]
# 006

# %%
nirfile=['/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/006/match_band_1',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/006/match_band_2',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/006/match_band_3',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/006/match_band_4',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/006/match_band_5',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR_match/006/match_band_6']
file=[0 for i in range(6)]
for i, a in enumerate(nirfile):
    if i>-1:    
        df=pd.read_csv(a,index_col=0)
        file[i]=df.drop_duplicates(subset=['col1_1'])
        # print(file[i])
    # print(df)
        # print(df[['FLUX_APER_1_Jy','FLUX_APER_2_Jy','FLUX_APER_Jy']])
    # print(df['aper70_flux'].iloc[0:5])
# file[2]



x=np.array([90,150,200,277,356,444,770,1000,1500])
y=[[] for i in range(len(file[0]))]
for j in range(len(file[0])):
                            
    y[j]+=[file[0]['Ra'].iloc[j],file[0]['Dec'].iloc[j]]
    for i in range(6):
    #  print(len(file[i]))
                                    
        y[j]+=[file[i]['aper70_flux'].iloc[j]]
        y[j]+=[file[i]['aper70_flux_err'].iloc[j]*sr2pix[i]*10**6]                                    
                                
        y[j]+=[-2.5*np.log10(np.abs(file[i]['aper70_flux'].iloc[j])/3631)]
        y[j]+=[2.5 *(file[i][ 'aper70_flux_err'].iloc[j]*sr2pix[i]*10**6/np.abs(file[i]['aper70_flux'].iloc[j]))/np.log(10)]
        # print(file[i][ 'aper70_flux_err'].iloc[j] *sr2pix[i]*10**6/ np.abs(file[i]['aper70_flux'].iloc[j]), file[i][ 'aper70_flux_err'].iloc[j],np.abs(file[i]['aper70_flux'].iloc[j]))
    
    y[j]+=[file[0]['FLUX_APER_1_Jy'].iloc[j],file[0]['FLUX_APER_1_Jy_err'].iloc[j],file[0]['MAG_APER_1_abmag'].iloc[j],file[0]['MAG_APER_1_abmag_err'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_2_Jy'].iloc[j],file[0]['FLUX_APER_2_Jy_err'].iloc[j],file[0]['MAG_APER_2_abmag'].iloc[j],file[0]['MAG_APER_2_abmag_err'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_Jy'].iloc[j],file[0]['FLUX_APER_Jy_err'].iloc[j],file[0]['MAG_APER_abmag'].iloc[j],file[0]['MAG_APER_abmag_err'].iloc[j]]


# sed_column=['jwst.nircam.F090W','jwst.nircam.F150W','jwst.nircam.F200W','jwst.nircam.F277W','jwst.nircam.F356W',
# 'jwst.nircam.F444W','jwst.miri.F770W','jwst.miri.F1000W','jwst.miri.F1500W']

sed_column_cigale=['jwst.nircam.F090W', 'jwst.nircam.F090W_err', 'jwst.nircam.F150W', 'jwst.nircam.F150W_err', 
'jwst.nircam.F200W','jwst.nircam.F200W_err','jwst.nircam.F277W', 'jwst.nircam.F277W_err', 
'jwst.nircam.F356W', 'jwst.nircam.F356W_err', 'jwst.nircam.F444W', 'jwst.nircam.F444W_err', 
'jwst.miri.F770W', 'jwst.miri.F770W_err', 'jwst.miri.F1000W', 'jwst.miri.F1000W_err', 
'jwst.miri.F1500W', 'jwst.miri.F1500W_err']

a=['F'+str(band)+'W'+'_flux' for i,band in enumerate(x)]
b=['F'+str(band)+'W'+'_flux_err' for i,band in enumerate(x)]
c=['F'+str(band)+'W'+'_mag' for i,band in enumerate(x)]
d=['F'+str(band)+'W'+'_mag_err' for i,band in enumerate(x)]
sed_column=['Ra','Dec']
for i in range(9):
    sed_column+=[a[i],b[i],c[i],d[i]]

id=[]
for i in range(len(file[0])):
    # print(file[0]['col1_1'].iloc[i])
    id.append(file[0]['col1_1'].iloc[i])


sed=pd.DataFrame(data=y,columns=sed_column,index=id)
sed_list=sed.fillna(99.0)
sed_list=sed_list.drop(index=[6,64])
sed_list.to_csv('NIR_match/sed_list_006.csv',index_label=' id')




sed_list_cigale=pd.DataFrame(data=y,index=id)
x=[]
for  i in range(10):    
    x+=[4*i,4*i+1]
# print(x)
sed_list_cigale=sed_list_cigale.drop(columns=x)
sed_list_cigale=sed_list_cigale.fillna(-99.0)
sed_list_cigale=sed_list_cigale.drop(index=[6,64])
sed_list_cigale.columns=sed_column_cigale
sed_list_cigale.insert(0, "redshift", [pz_006['z_best'].iloc[i] for i in range(len(sed_list_cigale['jwst.nircam.F090W']))], True)
sed_list_cigale.to_csv('NIR_match/sed_pz_006.txt',sep= ' ',index_label=' id')



# for i in range(len(y)):
#     yy=[y[i][4*j+2] for j in range(9)]
#     yer=[y[i][4*j+3] for j in range(9)]
#     plt.errorbar(x/100,yy,yerr=yer,fmt='o')
#     plt.title('006 '+ str(file[0]['col1_1'].iloc[i])+'lambda -flux plot')
#     plt.xlabel('wavelength(micron)')
#     plt.ylabel('flux(Jy)')
#     plt.xlim([0.8,17])
#     plt.xscale('log')
#     plt.yscale('log')
#     plt.savefig(f'NIR_match/006/wavelength_flux/wavelength_flux id'+str(file[0]['col1_1'].iloc[i])+'.png')
#     plt.close()


# for i in range(len(y)):
#     yy=[y[i][4*j+4] for j in range(9)]
#     yer=[y[i][4*j+5] for j in range(9)]
#     # print(yer)
#     plt.errorbar(x/100,yy,yerr=yer,fmt='o')
#     plt.title('006 '+ str(file[0]['col1_1'].iloc[i])+'lambda -abmag plot')
#     plt.xlabel('wavelength(micron)')
#     plt.ylabel('ABmag')
#     plt.xlim([0.8,17])
#     plt.xscale('log')
#     # print(i,max(yy)+1,min(yy)-1)
#     plt.ylim(np.nanmax(yy)+1,np.nanmin(yy)-1)
#     # plt.yscale('log')
#     plt.savefig(f'NIR_match/006/wavelength_flux/wavelength_ABmag id'+str(file[0]['col1_1'].iloc[i])+'.png')
#     plt.close()

# %%
plt.hist(x=sed_list['F90W_mag'][sed_list['F90W_mag']<99])
# Out:
# (array([ 2.,  2.,  5.,  2.,  3.,  1.,  5., 11.,  3.,  6.]),
#  array([20.70937424, 21.50922311, 22.30907199, 23.10892086, 23.90876973,
#         24.7086186 , 25.50846748, 26.30831635, 27.10816522, 27.90801409,
#         28.70786297]),
#  <BarContainer object of 10 artists>)

# %%
for i in range(len(sed_column)):
    if i !=-1:
        print(sed_list[sed_column[i]][sed_list[sed_column[i]]<0])
        print(i)
# sed_list[sed_list<0]
# Out:
# Series([], Name: Ra, dtype: float64)
# 0
# Series([], Name: Dec, dtype: float64)
# 1
# Series([], Name: F90W_flux, dtype: float64)
# 2
# Series([], Name: F90W_flux_err, dtype: float64)
# 3
# Series([], Name: F90W_mag, dtype: float64)
# 4
# Series([], Name: F90W_mag_err, dtype: float64)
# 5
# Series([], Name: F150W_flux, dtype: float64)
# 6
# Series([], Name: F150W_flux_err, dtype: float64)
# 7
# Series([], Name: F150W_mag, dtype: float64)
# 8
# Series([], Name: F150W_mag_err, dtype: float64)
# 9
# Series([], Name: F200W_flux, dtype: float64)
# 10
# Series([], Name: F200W_flux_err, dtype: float64)
# 11
# Series([], Name: F200W_mag, dtype: float64)
# 12
# Series([], Name: F200W_mag_err, dtype: float64)
# 13
# Series([], Name: F277W_flux, dtype: float64)
# 14
# Series([], Name: F277W_flux_err, dtype: float64)
# 15
# Series([], Name: F277W_mag, dtype: float64)
# 16
# Series([], Name: F277W_mag_err, dtype: float64)
# 17
# Series([], Name: F356W_flux, dtype: float64)
# 18
# ...

# %%
len(y),len(y[0])
# Out:
# (30, 18)

# %% [markdown]
# Red NIR and MIR merge catlog and sed plot（lanbda-flux)

# %%
nirfile=['/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR  match red/match band 1',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR  match red/match band 2',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR  match red/match band 3',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR  match red/match band 4',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR  match red/match band 5',
'/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/NIR  match red/match band 6']
file=[0 for i in range(6)]
for i, a in enumerate(nirfile):
    if i>-1:    
        df=pd.read_csv(a,index_col=0)
        file[i]=df.drop_duplicates(subset=['col1_1'])
        # print(file[i])
    # print(df)
        # print(df[['FLUX_APER_1_Jy','FLUX_APER_2_Jy','FLUX_APER_Jy']])
    # print(df['aper70_flux'].iloc[0:5])

# %%
x=np.array([90,150,200,277,356,444,770,1000,1500])
y=[[] for i in range(22)]
for j in range(22):
    for i in range(6):
        #  print(len(file[i]))

        y[j]+=[file[i]['aper70_flux'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_1_Jy'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_2_Jy'].iloc[j]]
    y[j]+=[file[0]['FLUX_APER_Jy'].iloc[j]]
        # y[j].append(file[0]['FLUX_APER_1_Jy'])
    # y[j].append(file[0]['FLUX_APER_2_Jy'])
    # y[j].append(file[0]['FLUX_APER_Jy'])

# %%
sed_column=['jwst.nircam.F090W','jwst.nircam.F150W','jwst.nircam.F200W','jwst.nircam.F277W','jwst.nircam.F356W',
'jwst.nircam.F444W','jwst.miri.F770W','jwst.miri.F1000W','jwst.miri.F1500W']

# %% [markdown]
# jwst.nircam.F090W, jwst.nircam.F150W, jwst.nircam.F200W, jwst.nircam.F277W, jwst.nircam.F356W, jwst.nircam.F444W, jwst.miri.F770W, jwst.miri.F1000W, jwst.miri.F1500W
#
#
# jwst.nircam.F090W, jwst.nircam.F090W_err, jwst.nircam.F150W, jwst.nircam.F150W_err, jwst.nircam.F200W, jwst.nircam.F200W_err, jwst.nircam.F277W, jwst.nircam.F277W_err,jwst.nircam.F356W, jwst.nircam.F356W_err, jwst.nircam.F444W,jwst.nircam.F444W_err, jwst.miri.F770W, jwst.miri.F770W_err, jwst.miri.F1000W, jwst.miri.F1000W_err, jwst.miri.F1500W, jwst.miri.F1500W_err

# %%
id=[]
for i in range(22):
    # print(file[0]['col1_1'].iloc[i])
    id.append(file[0]['col1_1'].iloc[i])

# %%
sed=pd.DataFrame(data=y,columns=sed_coloumn,index=id)
sed_list=sed.fillna(99.0)


sed_list.insert(0, "redshift", [99 for i in range(22)], True)
for i in range(9):
    sed_list.insert(2*i+2,sed_column[i]+'_err',[99 for i in range(22)])
sed_list.to_csv('NIR_match_red/sed_list.txt',sep= ' ',index_label=' id')

# %%
for i in range(22):
    plt.plot(x/100,y[i],'o')
    plt.title('lambda -flux plot')
    plt.xlabel('wavelength(micron)')
    plt.ylabel('flux(Jy)')
    plt.xscale('log')
    plt.yscale('log')
    plt.savefig(f'NIR match red/wavelength_flux/wavelength_flux id'+str(file[0]['col1_1'].iloc[i])+'.png')
    plt.close()

# %% [markdown]
# Processing Red sample re-calculate the flux and magnitude

# %%
df=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match',sep=',')
df
# Out:
#     col1_1  Number_1  EXT_NUMBER_1  FLUX_APER_1  FLUXERR_APER_1  MAG_APER_1  \
# 0        0       135             1    12.469840        0.137720     -2.7397
# 1        0       135             1    12.469840        0.137720     -2.7397
# 2        3       160             1    13.111320        0.137930     -2.7941
# 3        5       163             1   585.148200        0.138035     -6.9182
# 4       11       171             1     1.995790        0.138349     -0.7503
# 5       17       181             1    20.450280        0.137193     -3.2767
# 6       18       182             1    59.755490        0.138349     -4.4409
# 7       21       192             1   210.454600        0.137720     -5.8079
# 8       29       287             1    12.163370        0.137720     -2.7126
# 9       37       426             1    65.011220        0.137825     -4.5325
# 10      39       447             1     5.306575        0.137720     -1.8120
# ...

# %%
df['FLUX_APER_1_Jy']=df['FLUX_APER_1']*2.844*10**-7
# df['FLUX_APER_1_Jy_err']=df['FLUX_APER_1_Jy']*df['FLUXERR_APER_1']
df['FLUX_APER_1_Jy_err']=df['FLUXERR_APER_1']*2.844*10**-7
df['MAG_APER_1_abmag']=-2.5 * np.log10(df['FLUX_APER_1_Jy']/3631)
-2.5 * np.log10(df['FLUX_APER_1']/3631)
# df['FLUXERR_APER_1']/df['FLUX_APER_1']

# 2.5 * df['FLUX_APER_1_Jy_err']/df['FLUX_APER_1_Jy']/np.log(10)
# Out:
# 0     6.160413
# 1     6.160413
# 2     6.105950
# 3     1.981901
# 4     8.149779
# 5     5.623317
# 6     4.459121
# 7     3.092170
# 8     6.187431
# 9     4.367595
# 10    7.088030
# 11    6.190828
# 12    6.591050
# 13    5.745351
# 14    3.002133
# 15    7.759947
# 16    6.942969
# 17    3.559623
# 18    8.277543
# 19    4.813040
# 20    7.332072
# 21    6.523899
# 22    6.894780
# 23    5.470725
# 24    6.491910
# 25    5.856324
# 26    5.418562
# 27    7.539722
# 28    7.371951
# 29    6.837276
# 30    5.593514
# Name: FLUX_APER_1, dtype: float64

# %%
df['MAG_APER_1_abmag']=-2.5 * np.log10(df['FLUX_APER_1_Jy']/3631)
df

# %%
df=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match',sep=',')
#####Jy ****2.844*e-7 err also and calculate mag and mag_err
df['FLUX_APER_1_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['FLUX_APER_1_Jy_err']=df['FLUXERR_APER_1']*2.844*10**-7
df['MAG_APER_1_abmag']=-2.5 * np.log10(df['FLUX_APER_1_Jy']/3631)
df['MAG_APER_1_abmag_err']=2.5 * df['FLUX_APER_1_Jy_err']/df['FLUX_APER_1_Jy']/np.log(10)


df['FLUX_APER_2_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['FLUX_APER_2_Jy_err']=df['FLUXERR_APER_2']*2.844*10**-7
df['MAG_APER_2_abmag']=-2.5 * np.log10(df['FLUX_APER_2_Jy']/3631)
df['MAG_APER_2_abmag_err']=2.5 * df['FLUX_APER_2_Jy_err']/df['FLUX_APER_2_Jy']/np.log(10)


df['FLUX_APER_Jy']=df['FLUX_APER']*2.844*10**-7
df['FLUX_APER_Jy_err']=df['FLUXERR_APER']*2.844*10**-7
df['MAG_APER_abmag']=-2.5 * np.log10(df['FLUX_APER_Jy']/3631)
df['MAG_APER_abmag_err']=2.5 * df['FLUX_APER_Jy_err']/df['FLUX_APER_Jy']/np.log(10)

df=df[['col1_1','Number_1','Ra','Dec','FLUX_APER_1_Jy','FLUX_APER_1_Jy_err','MAG_APER_1_abmag','MAG_APER_1_abmag_err',
'FLUX_APER_2_Jy','FLUX_APER_2_Jy_err','MAG_APER_2_abmag','MAG_APER_2_abmag_err',
'FLUX_APER_Jy','FLUX_APER_Jy_err','MAG_APER_abmag','MAG_APER_abmag_err']]
df.to_csv('o002_mask_se_match_reflux.csv')



df=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o006_mask_se_match',sep=',')
df['FLUX_APER_1_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['FLUX_APER_1_Jy_err']=df['FLUXERR_APER_1']*2.844*10**-7
df['MAG_APER_1_abmag']=-2.5 * np.log10(df['FLUX_APER_1_Jy']/3631)
df['MAG_APER_1_abmag_err']=2.5 * df['FLUX_APER_1_Jy_err']/df['FLUX_APER_1_Jy']/np.log(10)


df['FLUX_APER_2_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['FLUX_APER_2_Jy_err']=df['FLUXERR_APER_2']*2.844*10**-7
df['MAG_APER_2_abmag']=-2.5 * np.log10(df['FLUX_APER_2_Jy']/3631)
df['MAG_APER_2_abmag_err']=2.5 * df['FLUX_APER_2_Jy_err']/df['FLUX_APER_2_Jy']/np.log(10)


df['FLUX_APER_Jy']=df['FLUX_APER']*2.844*10**-7
df['FLUX_APER_Jy_err']=df['FLUXERR_APER']*2.844*10**-7
df['MAG_APER_abmag']=-2.5 * np.log10(df['FLUX_APER_Jy']/3631)
df['MAG_APER_abmag_err']=2.5 * df['FLUX_APER_Jy_err']/df['FLUX_APER_Jy']/np.log(10)

df=df[['col1_1','Number_1','Ra','Dec','FLUX_APER_1_Jy','FLUX_APER_1_Jy_err','MAG_APER_1_abmag','MAG_APER_1_abmag_err',
'FLUX_APER_2_Jy','FLUX_APER_2_Jy_err','MAG_APER_2_abmag','MAG_APER_2_abmag_err',
'FLUX_APER_Jy','FLUX_APER_Jy_err','MAG_APER_abmag','MAG_APER_abmag_err']]
# df.to_csv('o002_mask_se_match_reflux.csv')
df.to_csv('o006_mask_se_match_reflux.csv')
df

df_002=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match_reflux.csv',sep=',',index_col=0)
df_006=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o006_mask_se_match_reflux.csv',sep=',',index_col=0)

# df_001=pd.concat([df_002,df_006])
# df_001.to_csv('o001_mask_se_match_reflux.csv')
# Out:
# /home/leolin/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/leolin/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_002
# Out:
#     col1_1  Number_1          Ra        Dec  FLUX_APER_1_Jy  \
# 0        0       135  339.028823  33.982873    3.546422e-06
# 1        0       135  339.028823  33.982873    3.546422e-06
# 2        3       160  339.034118  33.971733    3.728859e-06
# 3        5       163  339.025212  33.985627    1.664161e-04
# 4       11       171  339.027514  33.983507    5.676027e-07
# 5       17       181  339.024468  33.985651    5.816060e-06
# 6       18       182  339.030807  33.972307    1.699446e-05
# 7       21       192  339.031422  33.969325    5.985329e-05
# 8       29       287  339.028720  33.968285    3.459262e-06
# 9       37       426  339.014679  33.984533    1.848919e-05
# 10      39       447  339.012440  33.985452    1.509190e-06
# 11      41       472  339.021080  33.965578    3.448455e-06
# 12      44       488  339.021437  33.965122    2.385261e-06
# 13      45       490  339.019908  33.966919    5.197751e-06
# 14      55       800  338.968222  33.961658    6.502832e-05
# ...

# %%
df=pd.read_csv('o001_mask_se_match_reflux.csv',sep=',',index_col=0)
print(len(df))
df_dl=df[ (df['FLUX_APER_1_Jy']>0.24*10**-6) & (df['FLUX_APER_2_Jy']>0.52*10**-6) & (df['FLUX_APER_Jy']>1.45*10**-6) ]
print(len(df_dl))
df_dl.to_csv('source detection limit.csv')

df_dl_10times=df[ (df['FLUX_APER_1_Jy']>0.24*10**-5) & (df['FLUX_APER_2_Jy']>0.52*10**-5) & (df['FLUX_APER_Jy']>1.45*10**-5) ]

df_dl_10times.to_csv('source detection limit ten times.csv')
print(len(df_dl_10times))

# %%
df=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match_red',sep=',')
df['FLUX_APER_1_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['MAG_APER_1_abmag']=-2.5 * np.log10(df['FLUX_APER_1_Jy']/3631)

df['FLUX_APER_2_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['MAG_APER_2_abmag']=-2.5 * np.log10(df['FLUX_APER_2_Jy']/3631)

df['FLUX_APER_Jy']=df['FLUX_APER']*2.844*10**-7
df['MAG_APER_abmag']=-2.5 * np.log10(df['FLUX_APER_Jy']/3631)
df.to_csv('o002_mask_se_match_red_reflux.csv')
df

# %%
df=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o006_mask_se_match_red',sep=',')
df['FLUX_APER_1_Jy']=df['FLUX_APER_1']*2.844*10**-7
df['MAG_APER_1_abmag']=-2.5 * np.log10(df['FLUX_APER_1_Jy']/3631)

df['FLUX_APER_2_Jy']=df['FLUX_APER_2']*2.844*10**-7
df['MAG_APER_2_abmag']=-2.5 * np.log10(df['FLUX_APER_2_Jy']/3631)

df['FLUX_APER_Jy']=df['FLUX_APER']*2.844*10**-7
df['MAG_APER_abmag']=-2.5 * np.log10(df['FLUX_APER_Jy']/3631)
df.to_csv('o006_mask_se_match_red_reflux.csv')
df

# %%
df_002=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match_red_reflux.csv',sep=',',index_col=0)
df_006=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o006_mask_se_match_red_reflux.csv',sep=',',index_col=0)

df_001=pd.concat([df_002.drop(labels=[2,3]),df_006])
df_001.to_csv('o001_mask_se_match_red_reflux.csv')

# %% [markdown]
# Writing the regionfile for o002,o006 with 3bands 770,1000,1500

# %%
df=pd.read_csv('o001_mask_se_match_red_reflux.csv')
path=('regionfile/o001_NIR_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f770 abmag:' + str(df['MAG_APER_1_abmag'].loc[i])+ '}',file=k)
       
k.close()

# %%
df=pd.read_csv('o002_mask_se_match_red_reflux.csv')
path=('regionfile/o002_f770_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f770 abmag:' + str(df['MAG_APER_1_abmag'].loc[i])+ '}',file=k)
       
k.close()

path=('regionfile/o002_f1000_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f1000 abmag:' + str(df['MAG_APER_2_abmag'].loc[i])+ '}',file=k)
       
k.close()

path=('regionfile/o002_f1500_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f1500 abmag:' + str(df['MAG_APER_abmag'].loc[i])+ '}',file=k)
       
k.close()

# %%
df=pd.read_csv('o006_mask_se_match_red_reflux.csv')
path=('regionfile/o006_f770_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f770 abmag:' + str(df['MAG_APER_1_abmag'].loc[i])+ '}',file=k)
       
k.close()

path=('regionfile/o006_f1000_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f1000 abmag:' + str(df['MAG_APER_2_abmag'].loc[i])+ '}',file=k)
       
k.close()

path=('regionfile/o006_f1500_regionfile_red.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ',' + str(df['Y_IMAGE'].loc[i]) + ',18.031714) # text={id' + str(df['col1_1'].loc[i]) +' f1500 abmag:' + str(df['MAG_APER_abmag'].loc[i])+ '}',file=k)
k.close()

# %%
df['MAG_APER_abmag']

# %% [markdown]
# from Jimmy's catalog write X,Y into regionfile and put into DS9 and get the Ra,Dec
# Then open the regionfile to take the Ra, Dec out and put them into Jimmy's Catalog

# %%
import re

str = 'an example word:cat!!'
match = re.search(r'word:\w\w\w', str)
# If-statement after search() tests if it succeeded
if match:
  print('found', match.group()) ## 'found word:cat'
else:
  print('did not find')

# %%
print('scanf()')
pattern = re.compile(r"circle\((\S+),(\S+),(\S+)\"\)")
match = pattern.match('circle(339.0288015,33.9828664,2.000") # text={id0}\n')
# print(match.groups)
if match:
    print(match.groups())

# %%
catfile=['jw02732-o002_t001_miri_f770w_CUT.cat','D:\JWST-MIRI\jw02732-o002_t001_miri_f1000w\jw02732-o002_t001_miri_f1000w_CUT.cat',
'D:\JWST-MIRI\jw02732-o002_t001_miri_f1500w\jw02732-o002_t001_miri_f1500w_CUT.cat','D:\JWST-MIRI\jw02732-o006_t001_miri_f770w\jw02732-o006_t001_miri_f770w_CUT.cat',
'D:\JWST-MIRI\jw02732-o006_t001_miri_f1000w\jw02732-o006_t001_miri_f1000w_CUT.cat','D:\JWST-MIRI\jw02732-o006_t001_miri_f1500w\jw02732-o006_t001_miri_f1500w_CUT.cat']

txtfile=['o002_f770_region_RADEC','o002_f1000_region_RADEC','o002_f1500_region_RADEC',
'o006_f770_region_RADEC','o006_f1000_region_RADEC','o006_f1500_region_RADEC']

savefile=['o002_f770_region.csv','o002_f1000_region.csv','o002_f1500_region.csv',
'o006_f770_region.csv','o006_f1000_region.csv','o006_f1500_region.csv']

# %%
import re

df=pd.read_csv('jw02732-o002_t001_miri_f770w_CUT.cat',sep=',')
df = df.rename(columns={'Unnamed: 0':'Number'})

with open('o002_f770_region_RADEC.txt','r') as f:
    pattern = re.compile(r"circle\((\S+),(\S+),(\S+)\"\)")
    lines = f.readlines()
    info = [pattern.match(l).groups() for l in lines[3:-1]]

len(info)
# info

info_list=[[float(i) for i in l] for l in info]
df_info=pd.DataFrame(data=info_list,columns=['Ra','Dec','radius'])
data=pd.concat([df,df_info],axis=1)
data.to_csv('o002_f770_region.csv')

# %%
import re
for i in range(len(catfile)):
    df=pd.read_csv(catfile[i],sep=',')
    df = df.rename(columns={'Unnamed: 0':'Number'})

    with open(txtfile[i],'r') as f:
        pattern = re.compile(r"circle\((\S+),(\S+),(\S+)\"\)")
        lines = f.readlines()
        info = [pattern.match(l).groups() for l in lines[3:]]

    len(info)
    # info

    info_list=[[float(i) for i in l] for l in info]
    df_info=pd.DataFrame(data=info_list,columns=['Ra','Dec','radius'])
    data=pd.concat([df,df_info],axis=1)
    data.to_csv(savefile[i])

# %%
df=pd.read_csv('jw02732-o002_t001_miri_f770w_CUT.cat',sep=',' )
path=('o002_f770_region.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ','+ str(df['Y_IMAGE'].loc[i])+',18.031714) # text={id' + str(i) + '}',file=k)
       
k.close()

# %%
df=pd.read_csv('D:\JWST-MIRI\jw02732-o002_t001_miri_f1000w\jw02732-o002_t001_miri_f1000w_CUT.cat',sep=',' )
path=('o002_f1000_region.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ','+ str(df['Y_IMAGE'].loc[i])+',18.031714) # text={id' + str(i) + '}',file=k)
       
k.close()

# %%
df=pd.read_csv('D:\JWST-MIRI\jw02732-o002_t001_miri_f1500w\jw02732-o002_t001_miri_f1500w_CUT.cat',sep=',' )
path=('o002_f1500_region.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ','+ str(df['Y_IMAGE'].loc[i])+',18.031714) # text={id' + str(i) + '}',file=k)
       
k.close()

# %%
df=pd.read_csv('D:\JWST-MIRI\jw02732-o006_t001_miri_f770w\jw02732-o006_t001_miri_f770w_CUT.cat',sep=',' )
path=('o006_f770_region.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ','+ str(df['Y_IMAGE'].loc[i])+',18.031714) # text={id' + str(i) + '}',file=k)
       
k.close()

# %%
df=pd.read_csv('D:\JWST-MIRI\jw02732-o006_t001_miri_f1000w\jw02732-o006_t001_miri_f1000w_CUT.cat',sep=',' )
path=('o006_f1000_region.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i])[:8] + ','+ str(df['Y_IMAGE'].loc[i])[:8]+',18.031714) # text={id' + str(i) + '}',file=k)
       
k.close()

# %%
###### write NIR region


df=pd.read_csv('D:\JWST-MIRI\jw02732-o006_t001_miri_f1500w\jw02732-o006_t001_miri_f1500w_CUT.cat',sep=',' )
path=('o006_f1500_region.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('physical',file=k)

for i, a in enumerate(df['X_IMAGE']):
       print('circle(' + str(df['X_IMAGE'].loc[i]) + ','+ str(df['Y_IMAGE'].loc[i])+',18.031714) # text={id' + str(i) + '}',file=k)
       
k.close()

# %% [markdown]
# Writing region file for NIR sources
# First merge o002 and o006 catalog in to one region file

# %%
df_002=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match_red_reflux.csv',sep=',' )
df_006=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o006_mask_se_match_red_reflux.csv',sep=',' )

o002_id=[3,41,44]
o006_id=[8,32,47,51,195,200,202,206]

path=('NIRCAM_regionfile.txt')
k=open(path,'w')
print('# Region file format: DS9 version 4.1',file=k)
print('global color=green dashlist=8 3 width=1 font="helvetica 10 normal roman" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1',file=k)
print('fk5',file=k)

for i, a in enumerate(o002_id):
       print('circle(' + str(df_002[df_002['col1_1']==a]['Ra_1'].values[0]) + ','+ str(df_002[df_002['col1_1']==a]['Dec_1'].values[0])+',2") # text={o002 id' + str(a) + '}',file=k)


for i, a in enumerate(o006_id):
       print('circle(' + str(df_006[df_006['col1_1']==a]['Ra_1'].values[0]) + ','+ str(df_006[df_006['col1_1']==a]['Dec_1'].values[0])+',2") # text={o006 id' + str(a) + '}',file=k)
       
k.close()

# %%
df_002=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o002_mask_se_match_red_reflux.csv',sep=',' )
df_006=pd.read_csv('/home/leolin/JWST_data/MAST_2022-07-13T1114/miri_match/o006_mask_se_match_red_reflux.csv',sep=',' )
# a=df_002[df_002['col1_1']==44]['Ra_1']
# a=df_002[df_002['col1_1']==44]['Dec_1']
a=df_006[df_006['col1_1']==47]['Ra_1'].values[0]
# a[0]
# a[1]
a

# %%
df_002
